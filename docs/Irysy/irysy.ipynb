# %% [markdown]
# ### O Danych
#
# Zbiór danych zawiera informacje o trzech gatunkach irysów: Iris setosa, Iris versicolor, i Iris virginica.
# Dane obejmują pomiary czterech cech: długość i szerokość działki kielicha oraz długość i szerokość płatka.
# Każdy wiersz w zbiorze danych reprezentuje pojedynczy kwiat, a wartości pomiarów są podane w centymetrach.
# Zbiór składa się z 150 próbek, po 50 dla każdego gatunku, i jest szeroko stosowany jako podstawowy zbiór danych do
# testowania algorytmów klasyfikacji oraz w nauce o danych i uczeniu maszynowym.
#
# Kolumny:
# * **długość kielicha (sepal length)** - Długość kielicha w cm
# * **szerokość kielicha (sepal width)** - Szerokość kielicha w cm
# * **długość płatka (petal length)** - Długość płatka w cm
# * **szerokość płatka (petal width)** - Szerokość płatka w cm
# * **klasa (class)** - Klasa irysa (setosa, versicolor, virginica)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Ogólny przegląd danych

# %%
df = pd.read_csv('iris.csv', sep=",")
df
# Out:
#      długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# 0                                5.1                               3.5
# 1                                4.9                               3.0
# 2                                4.7                               3.2
# 3                                4.6                               3.1
# 4                                5.0                               3.6
# ..                               ...                               ...
# 145                              6.7                               3.0
# 146                              6.3                               2.5
# 147                              6.5                               3.0
# 148                              6.2                               3.4
# 149                              5.9                               3.0
#
#      długość płatka (petal length)  szerokość płatka (petal width)  \
# ...

# %% [markdown]
# ### 5 losowych wartości

# %%
#Zobaczmy 5 losowych wartości
df. sample (5)
# Out:
#      długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# 21                               5.1                               3.7
# 71                               6.1                               2.8
# 126                              6.2                               2.8
# 9                                4.9                               3.1
# 30                               4.8                               3.1
#
#      długość płatka (petal length)  szerokość płatka (petal width)  \
# 21                             1.5                             0.4
# 71                             4.0                             1.3
# 126                            4.8                             1.8
# 9                              1.5                             0.1
# 30                             1.6                             0.2
#
#        klasa (class)
# 21       Iris-setosa
# 71   Iris-versicolor
# 126   Iris-virginica
# 9        Iris-setosa
# 30       Iris-setosa

# %% [markdown]
# ### 5 pierwszych wartości

# %%
#Zobaczmy 5 pierwszych wartości
df. head (5)
# Out:
#    długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# 0                              5.1                               3.5
# 1                              4.9                               3.0
# 2                              4.7                               3.2
# 3                              4.6                               3.1
# 4                              5.0                               3.6
#
#    długość płatka (petal length)  szerokość płatka (petal width) klasa (class)
# 0                            1.4                             0.2   Iris-setosa
# 1                            1.4                             0.2   Iris-setosa
# 2                            1.3                             0.2   Iris-setosa
# 3                            1.5                             0.2   Iris-setosa
# 4                            1.4                             0.2   Iris-setosa

# %% [markdown]
# ### 5 ostatnich wartości

# %%
# I 5 ostatnich wartości 
df.tail(5)
# Out:
#      długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# 145                              6.7                               3.0
# 146                              6.3                               2.5
# 147                              6.5                               3.0
# 148                              6.2                               3.4
# 149                              5.9                               3.0
#
#      długość płatka (petal length)  szerokość płatka (petal width)  \
# 145                            5.2                             2.3
# 146                            5.0                             1.9
# 147                            5.2                             2.0
# 148                            5.4                             2.3
# 149                            5.1                             1.8
#
#       klasa (class)
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# Widzimy, że dane są ponumerowane od 0 do 149, więc przeprowadzonych było 150 pomiarów

# %% [markdown]
# ### Przyjrzyjmy się ilości wartości liczbowych

# %%
# Przyjrzyjmy się ilości wartości liczbowych 
df.groupby(['klasa (class)']).count()
# Out:
#                  długość kielicha (sepal length)  \
# klasa (class)
# Iris-setosa                                   50
# Iris-versicolor                               50
# Iris-virginica                                50
#
#                  szerokość kielicha (sepal width)  \
# klasa (class)
# Iris-setosa                                    50
# Iris-versicolor                                50
# Iris-virginica                                 50
#
#                  długość płatka (petal length)  szerokość płatka (petal width)
# klasa (class)
# Iris-setosa                                 50                              50
# Iris-versicolor                             50                              50
# Iris-virginica                              50                              50

# %% [markdown]
# ##### Widzimy, że są trzy odmiany Irysów, oraz że pomiary zostały wzięte od 50 kwiatów z każdej odmianie

# %% [markdown]
# ### Przyjrzyjmy się ogólnym informacjom o Date Frame

# %%
#Przyjrzyjmy się ogólnym inforamcjom o Date Frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   długość kielicha (sepal length)   150 non-null    float64
#  1   szerokość kielicha (sepal width)  150 non-null    float64
#  2   długość płatka (petal length)     150 non-null    float64
#  3   szerokość płatka (petal width)    150 non-null    float64
#  4   klasa (class)                     150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Analiza brakujących wartości

# %%
#Wyszukujemy brakujące wartości
df.isnull().sum()
# Out:
# długość kielicha (sepal length)     0
# szerokość kielicha (sepal width)    0
# długość płatka (petal length)       0
# szerokość płatka (petal width)      0
# klasa (class)                       0
# dtype: int64

# %% [markdown]
# Nie ma brakujących wartości

# %% [markdown]
# # Analiza pojedynczych zmiennych

# %%
df[['długość kielicha (sepal length)','szerokość kielicha (sepal width)']].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Patrząc na percentyle widać, że jego wielkośc rozkłada się równomiernie. Co oznacza że trudno jest odróżnić odmiany od siebie.
# Jednak jeśli chodzi o szerokość kielicha (sepal width) to widać dużo wartości odstających, które moga być pomocą w odróznianiu odmiany

# %% [markdown]
# ### Porównajmy długosć płatka do jego szerokości

# %%
df[['długość płatka (petal length)','szerokość płatka (petal width)']].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ### O wiele łatwiej odróżnić odmianę Irysa patrząc na płatki, ponieważ widzimy że długość i szerokość płatków jest bardziej "rozrzucona" jeśli chodzi o pomiary

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df_plot, x='class', y='sepal_length', hue='class', palette="Set2", legend=False)
plt.title("Długość kielicha (sepal length) – porównanie klas")
plt.xlabel("Klasa")
plt.ylabel("Długość kielicha")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Widzimy że najkrótsze są kielichy Iris setosa, a najdłuższe Iris virginica

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df_plot, x='class', y='sepal_length', hue='class', palette="Set2", legend=False)
plt.title("Szerokość kielicha (sepal width) – porównanie klas")
plt.xlabel("Klasa")
plt.ylabel("Szerokość kielicha")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Jeśli chodzi natomiast o szerkość kielicha to możemy zauważyć że najszerszy kielich posiada Iris setosa, a najsmuklejszy Iris versicolor

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df_plot, x='class', y='sepal_length', hue='class', palette="Set2", legend=False)
plt.title("Długość płatka (petal length) – porównanie klas")
plt.xlabel("Klasa")
plt.ylabel("Długość płatka")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Największą różnicę widzimy kiedy patrzymy na wielkość płatków. Zdecydowanie najdłużesz płatki ma Iris virginica, a najkrótsze Iris setosa

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df_plot, x='class', y='sepal_length', hue='class', palette="Set2", legend=False)
plt.title("Szerokość płatka (petal width) – porównanie klas")
plt.xlabel("Klasa")
plt.ylabel("Szerokość płatka")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Tak samo sytuacja wygląda kiedy patrzymy na szerokość płatków

# %%
subset_setosa = df[df['klasa (class)'] == 'Iris-setosa'].drop(columns='klasa (class)')
corr_setosa = subset_setosa.corr()

plt.figure(figsize=(6, 4))
sns.heatmap(corr_setosa, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Macierz korelacji – Iris-setosa")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### W przypadku iris setosa kiedy szerokość kielicha rośnie, wzrasta także długość kielicha. Jeśłi chodzi o pozostałe własności to korelacje są słabe.

# %%
subset_versicolor = df[df['klasa (class)'] == 'Iris-versicolor'].drop(columns='klasa (class)')
corr_versicolor = subset_versicolor.corr()

plt.figure(figsize=(6, 4))
sns.heatmap(corr_versicolor, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Macierz korelacji – Iris-versicolor")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### W przypadku iris versicolor jest więcej korelacji. Kiedy rośnie długość płatka, zwiększa się długość kielicha, a także rośnie szerokość płatka. Nie bez wpływu jest również szerokość kielicha, bo gdy ona rośnie wzrasta także prawdopodobieństwo, że zwiększy się szerokość płatka.

# %%
subset_virginica = df[df['klasa (class)'] == 'Iris-virginica'].drop(columns='klasa (class)')
corr_virginica = subset_virginica.corr()

plt.figure(figsize=(6, 4))
sns.heatmap(corr_virginica, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Macierz korelacji – Iris-virginica")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Kiedy mówimy o Iris virginica to bardzo wyraźnie widać korelację dodatnią między długością płatka, a długością kielicha.

# %%
# !jupyter nbconvert irysy_prezentacja.ipynb --to slides --no-input
# Out:
# [NbConvertApp] Converting notebook irysy_prezentacja.ipynb to slides
# [NbConvertApp] WARNING | Alternative text is missing on 9 image(s).
# [NbConvertApp] Writing 700563 bytes to irysy_prezentacja.slides.html
